# %% [markdown]
# # Test LaLigaAPI

# %% [markdown]
# # TEST Reading parquet files

# %%
# import parquets
import pandas as pd

# Load games from parquet file
games = pd.read_parquet('../data/parquet/games_stats_22_and_23.parquet')
games.tail()
# Out:
#                                               match_1  \
# 71  {'date': '2024-05-05T00:00:00.000Z', 'id': 331...
# 72  {'date': '2024-05-12T00:00:00.000Z', 'id': 341...
# 73  {'date': '2024-05-15T00:00:00.000Z', 'id': 351...
# 74  {'date': '2024-05-19T00:00:00.000Z', 'id': 361...
# 75  {'date': '2024-05-26T00:00:00.000Z', 'id': 371...
#
#                                               match_2  \
# 71  {'date': '2024-05-05T00:00:00.000Z', 'id': 332...
# 72  {'date': '2024-05-12T00:00:00.000Z', 'id': 342...
# 73  {'date': '2024-05-15T00:00:00.000Z', 'id': 352...
# 74  {'date': '2024-05-19T00:00:00.000Z', 'id': 362...
# 75  {'date': '2024-05-26T00:00:00.000Z', 'id': 372...
#
#                                               match_3  \
# 71  {'date': '2024-05-05T00:00:00.000Z', 'id': 333...
# 72  {'date': '2024-05-12T00:00:00.000Z', 'id': 343...
# 73  {'date': '2024-05-15T00:00:00.000Z', 'id': 353...
# 74  {'date': '2024-05-19T00:00:00.000Z', 'id': 363...
# ...

# %%
# Load players from parque file
players = pd.read_parquet('../data/parquet/players_22_and_23.parquet')
players.head()
# Out:
#                                                 images  positionId  \
# id
# 53   {'beat': {'1024x1024': 'https://assets-fantasy...         1.0
# 68   {'beat': {'1024x1024': 'https://assets-fantasy...         1.0
# 93   {'beat': {'1024x1024': 'https://assets-fantasy...         1.0
# 140  {'beat': {'1024x1024': 'https://assets-fantasy...         1.0
# 184  {'beat': {'1024x1024': 'https://assets-fantasy...         1.0
#
#         nickname  lastSeasonPoints playerStatus  marketValue  \
# id
# 53         Oblak             164.0      injured   29745523.0
# 68    Unai Simón             166.0           ok   27738350.0
# 93    Ter Stegen             284.0           ok   53294805.0
# 140  Iván Villar              85.0           ok    4992637.0
# 184  David Soria             237.0           ok   20050462.0
#
#                                                   team  points  averagePoints  \
# id
# 53   {'badgeColor': 'https://assets-fantasy.llt-ser...     0.0            0.0
# ...
